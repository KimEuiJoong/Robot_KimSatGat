# %%
import pandas as pd
import numpy as np
import pickle

poems = pd.read_csv('C:\DeepLearing\Robot_KSG\poem\poems.csv', names=['name','writer','text','cc'])
with open('C:\DeepLearing\Robot_KSG\Softmax_Regression\poemIndex_intTag', 'rb') as fr:
    poems_tag = pickle.load(fr)

poems = poems.iloc[:,0:3]
poems['tag'] = poems_tag
poems.fillna('#', inplace=True)

poems
# Out:
#                                   name writer  \
# 0                       1, 2, 3, 4선생-1   서덕출
# 1                              10월의 노래   조명희
# 2                                 15일간   박인환
# 3     1926년 3월 19일 야심(一九二六年三月十九日夜心)-36   김창술
# 4                      1929년(一九二九年)-35   김창술
# ...                                ...    ...
# 4868                             落葉-22   김대봉
# 4869                           落葉소리-23   김대봉
# 4870                            論介(논개)   변영로
# 4871                        六花六稜(육화육릉)   변영로
# 4872                        履聲滿街(이성만가)   변영로
#
#                                                    text tag
# 0     1,  2,  3,  4,  선생\n\n서덕출\n\n나는  학교  조그마한\n\n학...   6
# 1     10\n\n월의 노래\n\n짓밟힌 무리의 흘린 핏방울 방울이\n\n지심으로 흘러 흘...   9
# 2     일간15\n\n깨끗한 시트 위에서\n\n나는 몸부림을 쳐도 소용이 없다.\n\n공간...  12
# 3     一九二六年三月十九日夜心\n\n김창술\n\n독와사를  퍼트린드시  숨맥히는이밤의마음에...   #
# 4     一九二九年\n\n김창술\n\n울엉찬새벽고동이  잠들은이을  흔들어  우네\n\n...   9
# ...                                                 ...  ..
# 4868  확실히  落葉소리  인데\n\n落葉소리는  들리지안허\n\n萬衆을  지씹는\n\n暴...   #
# 4869  落葉소리\n\n김대봉\n\n찬서리  나리는  고요한밤에\n\n낙엽이  바싸싹  러...   #
# 4870  論介\n\n논개[\n\n]\n\n거룩한  분노는\n\n종교보다도  깊고\n\n불붙는...   #
# 4871  [\n\n육화육릉\n\n]\n\n[\n\n]\n향락 같이 \n\n短\n\n[\n단명...   #
# 4872  街燈\n\n[\n\n가등 마저  졸음  못  참는  밤거리에\n\n]\n\n街\n\...   #
#
# [4873 rows x 4 columns]
